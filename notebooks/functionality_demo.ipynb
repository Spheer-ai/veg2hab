# %%
from pathlib import Path

import sys
sys.path.append('../')
from veg2hab.vegkartering import ProtoKartering

# %%
shape_path = Path("../testing/Rottige_Meenthe_Brandemeer_2013/vlakken.shp")
shp_elm_id_column = "ElmID"
access_csvs_path = Path("../testing/Rottige_Meenthe_Brandemeer_2013/864_RottigeMeenthe2013/")
proto = ProtoKartering.from_access_db(shape_path, shp_elm_id_column, access_csvs_path)
proto.gdf
# Out:
#       ElmID     Datum  Projcode       Opp      Dlgebied Opmerking  \
# 0     28049  19072013       864  0.376174       RM-Kern      None
# 1     15034  10092013       864  1.044266       RM-Oost      None
# 2     13503  14102013       864  0.217410      RM-Noord      None
# 3     15075  12092013       864  1.887805       RM-Oost      None
# 4     20502  02102013       864  0.495061       RM-Kern      None
# ...     ...       ...       ...       ...           ...       ...
# 1944  25047  22082013       864  0.092911  Scherpenzeel      None
# 1945  25050  22082013       864  0.090002  Scherpenzeel      None
# 1946  26013  28082013       864  0.011078       RM-Kern      None
# 1947  26313  29082013       864  0.274077       RM-Kern      None
# 1948  26314  29082013       864  0.336659       RM-Kern      None
#
#                            VegType        LabelKaart  \
# 0                  09A2-6.e,h,v.90         09A2-6(2)
# 1                          50A-1.e             50A-1
# ...

# %%
for i in proto.gdf.VegTypeInfo[4]:
    print(i)
# Out:
# (58%, vvn: 'None', sbb: '08B3c')
# (29%, vvn: 'None', sbb: '08C-c')
# (10%, vvn: 'None', sbb: '09-g')
# (3%, vvn: 'None', sbb: '05D5a')
