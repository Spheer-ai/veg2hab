# %% [markdown]
# # Validate some predictions

# %%
import geopandas as gpd
import pandas as pd
from typing import List, Optional, Dict

from veg2hab import validation

pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)
# Out:
# /home/jordydelange/.cache/pypoetry/virtualenvs/veg2hab-CuqoUkZb-py3.7/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.11.2-CAPI-1.17.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# ### Inlezen van de data

# %%
gdf_pred_raw = gpd.read_file('../testing/omgezette_vegetatiekarteringen/GR/SGL Zuidlaardermeer 2019.shp')
gdf_pred_raw.head(2)
# Out:
#           Area  Opm       Datum  _ChkNodig Habtype1 Perc1               Opp1     Kwal1                                               Opm1   VvN1  SBB1                               _Status1     _VvNdftbl1 _SBBdftbl1                            _VgTypInf1  _ChkNodig1 Habtype2 Perc2               Opp2     Kwal2                                               Opm2    VvN2  SBB2                               _Status2 _VvNdftbl2     _SBBdftbl2                              _VgTypInf2 _ChkNodig2 Habtype3 Perc3               Opp3     Kwal3                                               Opm3   VvN3  SBB3                          _Status3     _VvNdftbl3 _SBBdftbl3                            _VgTypInf3 _ChkNodig3 Habtype4 Perc4               Opp4 Kwal4  Opm4  VvN4  SBB4                               _Status4 _VvNdftbl4 _SBBdftbl4  ... _ChkNodig5 Habtype6 Perc6  Opp6 Kwal6  Opm6  VvN6  SBB6 _Status6 _VvNdftbl6 _SBBdftbl6 _VgTypInf6 _ChkNodig6 Habtype7 Perc7 Opp7 Kwal7  Opm7  VvN7  SBB7 _Status7  \
# 0  3692.336448  nvt  20190715.0          1    HXXXX    19  70154.39251248693  Onbekend  Er zijn mitsen met nog niet geimplementeerde c...  8bc2a  None       KeuzeStatus.PLACEHOLDER_CRITERIA  ['8bc2', 249]       None  (19%, VvN: ['8bc2a'], SBB: ['8c2c'])           1    HXXXX    19  70154.39251248693  Onbekend  Er zijn mitsen met nog niet geimplementeerde c...    None  8c-d       KeuzeStatus.PLACEHOLDER_CRITERIA       None  ['8c-d', 258]           (19%, VvN: [], SBB: ['8c-d'])          1    HXXXX    10  36923.36448025628  Onbekend  Er zijn mitsen met nog niet geimplementeerde c...  8bc2a  None  KeuzeStatus.PLACEHOLDER_CRITERIA  ['8bc2', 249]       None  (10%, VvN: ['8bc2a'], SBB: ['8c2c'])          1    H0000    49  180924.4859532558  None  None  None  16-j  KeuzeStatus.VEGTYPEN_NIET_IN_DEFTABEL       None       None  ...          0     None  None  None  None  None  None  None     None       None       None       None       None     None   NaN  NaN  None  None  None  None     None
# 1  1238.369197  nvt  20190715.0          0    H0000    70  86685.84377139427      None                                               None   None  16-g  KeuzeStatus.VEGTYPEN_NIET_IN_DEFTABEL           None       None         (70%, VvN: [], SBB: ['16-g'])           0    H0000    30  37151.07590202612      None                                               None  16bc1a  None  KeuzeStatus.VEGTYPEN_NIET_IN_DEFTABEL       None           None  (30%, VvN: ['16bc1a'], SBB: ['16c4a'])          0     None  None               None      None                                               None   None  None                              None           None       None                                  None       None     None  None               None  None  None  None  None                                   None       None       None  ...       None     None  None  None  None  None  None  None     None       None       None       None       None     None   NaN  NaN  None  None  None  None     None
#
#   _VvNdftbl7 _SBBdftbl7 _VgTypInf7 _ChkNodig7 Habtype8 Perc8  Opp8  Kwal8  Opm8  VvN8  SBB8 _Status8 _VvNdftbl8 _SBBdftbl8 _VgTypInf8 _ChkNodig8 Habtype9 Perc9  Opp9  Kwal9  Opm9  VvN9  SBB9 _Status9 _VvNdftbl9 _SBBdftbl9 _VgTypInf9 _ChkNodig9                                           geometry
# 0       None       None       None       None     None   NaN   NaN   None  None  None  None     None       None       None       None       None     None   NaN   NaN   None  None  None  None     None       None       None       None       None  POLYGON ((242077.412 573207.577, 242082.572 57...
# 1       None       None       None       None     None   NaN   NaN   None  None  None  None     None       None       None       None       None     None   NaN   NaN   None  None  None  None     None       None       None       None       None  POLYGON ((243824.566 573054.300, 243860.398 57...
#
# [2 rows x 113 columns]

# %%
gdf_pred_raw.Habtype1.value_counts()
# Out:
# HXXXX      635
# H0000      133
# H7140_B     15
# Name: Habtype1, dtype: int64

# %%
gdf_true_raw = gpd.read_file("../testing/Habitatkarteringen/Habitattypekaarten Gr/NaamGebied_Oeverlanden Zuidlaardermeergebied.gpkg")
gdf_true_raw.head(2)
# Out:
#                           NaamGebied Habitattyp  Jaar                             Deelgebied StikstofGe Habtype1 Habtype2 Habtype3  Shape_Leng   Shape_Area    Opp_ha                                           geometry
# 0  Oeverlanden Zuidlaardermeergebied      H0000  2019  Groningen : Kruishammen tot Meerwijck       None    H0000     None     None  411.040756  3692.339806  0.369234  MULTIPOLYGON (((242095.272 573036.126, 242086....
# 1  Oeverlanden Zuidlaardermeergebied      H0000  2019                    Groningen: Leinwijk       None    H0000     None     None  491.252931  1238.370680  0.123837  MULTIPOLYGON (((243824.566 573054.300, 243860....

# %%
# minder dan 1% van de data bevat meer dan 1 habitattype
gdf_true_raw.Habtype2.notnull().mean()
# Out:
# 0.007662835249042145

# %%
print(gdf_true_raw.Habtype1.value_counts())
print(gdf_true_raw.Habtype2.value_counts())
# Out:
# H0000      771
# H7140_B     12
# Name: Habtype1, dtype: int64
# H0000      5
# H7140_B    1
# Name: Habtype2, dtype: int64

# %% [markdown]
# ### Convert to a single columned dataset

# %%
gdf_pred = validation.parse_habitat_percentages(gdf_pred_raw)

# %%
gdf_true = validation.parse_habitat_percentages(gdf_true_raw, percentage_cols=None, how_to_handle_missing_percentages="split_equally")

# %% [markdown]
# ### Combine datasets

# %%
gdf_combined = validation.spatial_join(gdf_pred, gdf_true, how="intersection")
# Out:
# /home/jordydelange/git/veg2hab/veg2hab/validation.py:163: UserWarning: Dropping 3769 rows based on area (presumed rounding errors) with a combined area of 2.946588855655696 m²
#   f"Dropping {mask.sum()} rows based on area (presumed rounding errors) with a combined area of {overlayed[mask].area.sum()} m²"

# %%
output_gdf = validation.voeg_correctheid_toe_aan_df(gdf_combined)
output_gdf.head(2)
# Out:
#                     pred_hab_perc     true_hab_perc                                           geometry  percentage_correct  oppervlakte_correct
# 0  {'HXXXX': 48.0, 'H0000': 52.0}  {'H0000': 100.0}  POLYGON ((242082.572 573196.861, 242081.572 57...                52.0         192001.37087
# 9                  {'HXXXX': 100}  {'H0000': 100.0}  POLYGON ((242048.039 573126.390, 242047.638 57...                 0.0              0.00000

# %%
output_gdf.to_file("../testing/correctheid_percentage_intersection.gpkg", driver="GPKG")

# %% [markdown]
# #### Create confusion matrix

# %%
validation.bereken_volledige_conf_matrix(gdf_combined, method="area")
# Out:
# true_hab       H0000   H7140_B  HXXXX
# pred_hab
# H0000     123.611986  0.035147    0.0
# H7140_B     0.314803  3.464846    0.0
# HXXXX     686.294541  0.275110    0.0

# %%
validation.bereken_volledige_conf_matrix(gdf_combined, method="percentage")
# Out:
# true_hab   H0000  H7140_B  HXXXX
# pred_hab
# H0000     318.05     0.14    0.0
# H7140_B     1.19     8.80    0.0
# HXXXX     453.76     1.06    0.0
